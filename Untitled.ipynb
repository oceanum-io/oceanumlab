# %%
from oceanum.datamesh import Connector, Query

# %%
q=Query(**{
    "datasource":"oceanum_global_multiscale_tidegrid",
    "parameters":{},
    "variables":["u","v","h"],
    "geofilter":{"type":"feature","geom":{"type":"Feature","geometry":{"type":"MultiPoint","coordinates":[[2.0,52.0]]}}}
                        })

# %%
datamesh=Connector()

# %%
ds=datamesh.query(q)

# %%
ds
# Out:
# <xarray.Dataset> Size: 864B
# Dimensions:      (con: 14, point: 1)
# Coordinates:
#   * con          (con) <U3 168B 'M2' 'S2' 'N2' 'K2' ... 'M4' 'MN4' 'MS4' '2N2'
#     lon          (point) float64 8B 2.0
#     lat          (point) float64 8B 52.0
#     spatial_ref  int64 8B 0
# Dimensions without coordinates: point
# Data variables:
#     u_re         (con, point) float64 112B 0.2384 -0.03971 ... 0.001665 0.009558
#     u_im         (con, point) float64 112B -0.3207 -0.1206 ... -0.0003422
#     v_re         (con, point) float64 112B 0.4518 -0.04929 ... -0.002913 0.01653
#     v_im         (con, point) float64 112B -0.5449 -0.2169 ... -0.001683
#     h_re         (con, point) float64 112B 0.7295 0.2299 ... 0.01638 0.002702
#     h_im         (con, point) float64 112B 0.4519 -0.06285 ... -0.03489 0.01718
# Attributes:
#     description:           Oceantide tidal constituents
#     version:               v0.2
#     _coordinates:          {"t":"time","x":"lon","y":"lat"}
# ...
